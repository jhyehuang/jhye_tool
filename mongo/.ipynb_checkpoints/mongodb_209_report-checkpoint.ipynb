# %%
from  lib.mongo_db  import db_conn
import pandas as pd
import numpy as np
from pyecharts import Bar,configure
configure(output_image='svg')

# %%
import time
def time_to_today(timeStamp):
    timeArray = time.localtime(int(timeStamp))
    timeArray =time.strftime("%Y-%m-%d %H:%I:%S",timeArray)
    return timeArray   # 2013

# %%
tel='13265009661'

# %% [markdown]
# ###  分析 13265009661 客户4次不同的查询中详单情况
# 交叉时间段中，详单均一致

# %%
data=db_conn.sid_info.find({'tel':tel,'status':0},{'sid':1,'end_time':1,'_id':0})
data=list(data)
ret=[]
bar1 = Bar(tel,'Theme',renderer ='svg')
for x in data:
    sid=x['sid']
    end_time=time_to_today(x['end_time'])
    call_log=db_conn.call_log.find({'sid':sid})
    det=pd.DataFrame(x for x in call_log)
    v1 = det['month'].value_counts()
    str1 = v1.index.tolist()
    ret=ret+str1
ret=list(set(ret))
ret_dict={}
for x in data:
    sid=x['sid']
    end_time=time_to_today(x['end_time'])
    call_log=db_conn.call_log.find({'sid':sid})
    det=pd.DataFrame(x for x in call_log)
    v1 = det['month'].value_counts()
    str1 = v1.index
    for x,y in zip(str1,v1):
        ret_dict[x]=y
    for x in ret:
        if x not in ret_dict:
            ret_dict[x]=0
    str1=list(ret_dict.keys())
    str1.sort()
    bar1.add(sid+' '+end_time,str1,list(ret_dict.values()),is_more_utils = True,is_smooth=True)
bar1
# Out:
# phantomjs version: 2.1.1

# %% [markdown]
# ### 分析详单中 call_time 情况
# call_time分布和month分布一致

# %%
import time
def time_to_month(timeStamp):
    timeArray = time.localtime(int(timeStamp))
    timeArray =time.strftime("%Y%m",timeArray)
    return timeArray   # 2013

# %%
data=db_conn.sid_info.find({'tel':tel,'status':0},{'sid':1,'end_time':1,'_id':0})
data=list(data)
ret=[]
bar2 = Bar(tel,'Theme',renderer ='svg')
for x in data:
    sid=x['sid']
    end_time=time_to_today(x['end_time'])
    call_log=db_conn.call_log.find({'sid':sid})
    det=pd.DataFrame(x for x in call_log)
    det['call_time']=det['call_time'].apply(lambda x:time_to_month(x))
    v1 = det['call_time'].value_counts()
    str1 = v1.index.tolist()
    ret=ret+str1
ret=list(set(ret))
ret_dict={}
for x in data:
    sid=x['sid']
    end_time=time_to_today(x['end_time'])
    call_log=db_conn.call_log.find({'sid':sid})
    det=pd.DataFrame(x for x in call_log)
    det['call_time']=det['call_time'].apply(lambda x:time_to_month(x))
    v1 = det['call_time'].value_counts()
    str1 = v1.index
    for x,y in zip(str1,v1):
        ret_dict[x]=y
    for x in ret:
        if x not in ret_dict:
            ret_dict[x]=0
    str1=list(ret_dict.keys())
    str1.sort()
    bar2.add(sid+' '+end_time,str1,list(ret_dict.values()),is_more_utils = True,is_smooth=True)
bar2

# %% [markdown]
# ### 分析生产环境存在静默的报告中的时间分布
# #### 随机获取1000个报告
# ##### 1、静默开始时间无明显规律
# ##### 2、静默结束时间无明显规律

# %%
import time
def time_to_day(timeStamp):
    timeArray = time.localtime(int(timeStamp))
    timeArray =time.strftime("%m%d",timeArray)
    return timeArray

# %%
def pri_tu(call_log):
    begin_day={}
    end_day={}
    for values in call_log:
        sid=values['sid']
        blank_times_list=values['calls_overview']['blank_times_list']
        if len(blank_times_list)>0:
            for one in blank_times_list:
                one[0]=time_to_day(one[0])
                one[1]=time_to_day(one[1])
                if one[0] in begin_day.keys():
                    begin_day[one[0]]=begin_day[one[0]]+1
                else:
                    begin_day[one[0]]=1
                if one[1] in end_day.keys():
                    end_day[one[1]]=end_day[one[1]]+1
                else:
                    end_day[one[1]]=1
    bar= Bar('day_anly','Theme',renderer ='svg')
    str1=list(begin_day.keys())
    str1.sort()
    bar.add('begin_day',str1,list(begin_day.values()),is_more_utils = True,is_smooth=True)
    str1=list(end_day.keys())
    str1.sort()
    bar.add('end_day',str1,list(end_day.values()),is_more_utils = True,is_smooth=True)
    
    return bar

# %%
call_log=db_conn.report.find({'calls_overview.blank_times_list':{'$exists':True,'$ne':[]}},{'_id':0,'calls_overview':1,'sid':1}).limit(1000)
call_log=list(call_log)
pri_tu(call_log)

# %%
data=db_conn.sid_info.find({'tel':tel,'status':0},{'sid':1,'_id':0})
ret={}
for x in list(data):
    sid=x['sid']
    report=db_conn.report.find_one({'sid':sid})
    ret[sid]=report['calls_overview']

# %%
import time
def time_to_today(timeStamp):
    timeArray = time.localtime(int(timeStamp))
    timeArray =time.strftime("%Y-%m-%d %H:%I:%S",timeArray)
    return timeArray   # 2013

# %%
print('tel:',tel)
for sid,values in ret.items():
    print('sid:',sid)
    blank_times_list=values.get('blank_times_list','')
    if len(blank_times_list)>0:
        for one in blank_times_list:
            call_log=db_conn.call_log.find({'sid':sid})
            pd_call=pd.DataFrame(x for x in call_log)
            if pd_call.shape[0]>0:
                pd_call=pd_call.loc[np.logical_and(pd_call.call_time>one[0],pd_call.call_time<one[1]),:]
                one.append(pd_call.shape[0])
                print(pd_call['call_time'])
                one.append(pd_call['month'].tolist())
            one[0]=time_to_today(one[0])
            one[1]=time_to_today(one[1])
            print(one )
    else:
        print(blank_times_list)
# Out:
# tel: 13265009661
# sid: SIDed39113350264533bd2a0c232585f4b4
#
# sid: SIDb486c46cc7804495b9bc29ea13ebf4ad
#
# sid: SIDdc27fc7928654839aa9eea53a0b821f4
#
# sid: SIDf854e8baedbf476d930a773ac355e829
# Series([], Name: call_time, dtype: object)
# ['2018-09-04 13:01:05', '2018-09-07 20:08:53', '78.71', 0, []]
# Series([], Name: call_time, dtype: object)
# ['2018-07-30 11:11:46', '2018-08-11 09:09:56', '286.29', 0, []]
# Series([], Name: call_time, dtype: object)
# ['2018-07-21 12:12:17', '2018-07-28 11:11:57', '167.84', 0, []]
# Series([], Name: call_time, dtype: object)
# ['2018-07-11 18:06:25', '2018-07-19 10:10:52', '184.24', 0, []]
# Series([], Name: call_time, dtype: object)
# ['2018-07-06 20:08:48', '2018-07-11 10:10:45', '109.95', 0, []]
# Series([], Name: call_time, dtype: object)
# ['2018-06-22 10:10:32', '2018-07-06 20:08:48', '346.54', 0, []]
# Series([], Name: call_time, dtype: object)
# ['2018-06-15 17:05:26', '2018-06-21 11:11:09', '138.41', 0, []]
# Series([], Name: call_time, dtype: object)
# ['2018-06-05 20:08:24', '2018-06-12 15:03:55', '162.99', 0, []]
# Series([], Name: call_time, dtype: object)
# ['2018-05-10 22:10:44', '2018-06-05 20:08:24', '621.79', 0, []]
# Series([], Name: call_time, dtype: object)
# ['2018-05-01 00:12:00', '2018-05-09 13:01:06', '205.67', 0, []]

# %% [markdown]
# ### 取5000个联通存在静默联通报告分析

# %%
call_log=db_conn.report.find({'calls_overview.blank_times_list':{'$exists':True,'$ne':[]},'call_behavior.number_used.telecom':'联通'},{'_id':0,'calls_overview':1,'sid':1}).limit(5000)
call_log=list(call_log)
pri_tu(call_log)

# %% [markdown]
# 9.30--10.3

# %%
call_log=db_conn.report.find({'calls_overview.blank_times_list':{'$exists':True,'$ne':[]},'call_behavior.number_used.telecom':'联通','created_at':{'$gte':1538236800,'$lte':1538409600}},{'_id':0,'calls_overview':1,'sid':1})
call_log=list(call_log)
pri_tu(call_log)

# %% [markdown]
# ### 10.7

# %%
call_log=db_conn.report.find({'calls_overview.blank_times_list':{'$exists':True,'$ne':[]},'call_behavior.number_used.telecom':'联通','created_at':{'$gte':1538841600,'$lte':1538928000}},{'_id':0,'calls_overview':1,'sid':1})
call_log=list(call_log)
pri_tu(call_log)

# %% [markdown]
# ### 10.8

# %%
call_log=db_conn.report.find({'calls_overview.blank_times_list':{'$exists':True,'$ne':[]},'call_behavior.number_used.telecom':'联通','created_at':{'$gte':1538928000,'$lte':1539014400}},{'_id':0,'calls_overview':1,'sid':1})
call_log=list(call_log)
pri_tu(call_log)

# %% [markdown]
# ### 10.9

# %%
call_log=db_conn.report.find({'calls_overview.blank_times_list':{'$exists':True,'$ne':[]},'call_behavior.number_used.telecom':'联通','created_at':{'$gte':1539014400,'$lte':1539100800}},{'_id':0,'calls_overview':1,'sid':1})
call_log=list(call_log)
pri_tu(call_log)

# %% [markdown]
# ### 5.7

# %%
call_log=db_conn.report.find({'calls_overview.blank_times_list':{'$exists':True,'$ne':[]},'call_behavior.number_used.telecom':'联通','created_at':{'$gte':1525622400,'$lte':1525708800}},{'_id':0,'calls_overview':1,'sid':1})
call_log=list(call_log)
pri_tu(call_log)

# %% [markdown]
# 10.1--10.7

# %%
call_log=db_conn.report.find({'calls_overview.blank_times_list':{'$exists':True,'$ne':[]},'call_behavior.number_used.telecom':'联通','created_at':{'$gte':1538323200,'$lte':1539014400}},{'_id':0,'calls_overview':1,'sid':1})
call_log=list(call_log)
pri_tu(call_log)

# %% [markdown]
# 8.1--8.7

# %%
call_log=db_conn.report.find({'calls_overview.blank_times_list':{'$exists':True,'$ne':[]},'call_behavior.number_used.telecom':'联通','created_at':{'$gte':1533052800,'$lte':1533571200}},{'_id':0,'calls_overview':1,'sid':1})
call_log=list(call_log)
pri_tu(call_log)

# %% [markdown]
# ### xinde  10-2 ---10.7

# %%
data=db_conn.sid_info.find({'end_time':{'$gte':1538409600,'$lte':1538928000},'status':0,'crawler_channel':'xinde'},{'_id':0,'sid':1})
data=list(data)
reports=[]
sids=[]
for one in data:
    sid=one['sid']
    sids.append(sid)

# %%
call_log=db_conn.report.find({'sid':{'$in':sids},'call_behavior.number_used.telecom':'中国联通','calls_overview.blank_times_list':{'$exists':True,'$ne':[]}},{'_id':0,'calls_overview':1,'sid':1})

#call_log=db_conn.report.find({'sid':{'$in':sids},'calls_overview.blank_times_list':{'$exists':True,'$ne':[]},'call_behavior.number_used.telecom':'中国联通'},{'_id':0,'calls_overview':1,'sid':1})
call_log=list(call_log)

# %%
pri_tu(call_log)

# %% [markdown]
# ### yulore 10.1--10.7

# %%
data=db_conn.sid_info.find({'end_time':{'$gte':1538323200,'$lte':1538928000},'status':0,'crawler_channel':{'$exists':False}},{'_id':0,'sid':1})
data=list(data)
reports=[]
sids=[]
for one in data:
    sid=one['sid']
    sids.append(sid)
call_log=db_conn.report.find({'sid':{'$in':sids},'call_behavior.number_used.telecom':'联通','calls_overview.blank_times_list':{'$exists':True,'$ne':[]}},{'_id':0,'calls_overview':1,'sid':1})

#call_log=db_conn.report.find({'sid':{'$in':sids},'calls_overview.blank_times_list':{'$exists':True,'$ne':[]},'call_behavior.number_used.telecom':'中国联通'},{'_id':0,'calls_overview':1,'sid':1})
call_log=list(call_log)
pri_tu(call_log)

# %% [markdown]
# ### yulore 10.7--10.7

# %%
data=db_conn.sid_info.find({'end_time':{'$gte':1538841600,'$lte':1538928000},'status':0,'crawler_channel':{'$exists':False}},{'_id':0,'sid':1})
data=list(data)
reports=[]
sids=[]
for one in data:
    sid=one['sid']
    sids.append(sid)
call_log=db_conn.report.find({'sid':{'$in':sids},'call_behavior.number_used.telecom':'联通','calls_overview.blank_times_list':{'$exists':True,'$ne':[]}},{'_id':0,'calls_overview':1,'sid':1})

#call_log=db_conn.report.find({'sid':{'$in':sids},'calls_overview.blank_times_list':{'$exists':True,'$ne':[]},'call_behavior.number_used.telecom':'中国联通'},{'_id':0,'calls_overview':1,'sid':1})
call_log=list(call_log)
pri_tu(call_log)

# %% [markdown]
# ### yulore 10.8--10.8

# %%
data=db_conn.sid_info.find({'end_time':{'$gte':1538928000,'$lte':1539014400},'status':0,'crawler_channel':{'$exists':False}},{'_id':0,'sid':1})
data=list(data)
reports=[]
sids=[]
for one in data:
    sid=one['sid']
    sids.append(sid)
call_log=db_conn.report.find({'sid':{'$in':sids},'call_behavior.number_used.telecom':'联通','calls_overview.blank_times_list':{'$exists':True,'$ne':[]}},{'_id':0,'calls_overview':1,'sid':1})

#call_log=db_conn.report.find({'sid':{'$in':sids},'calls_overview.blank_times_list':{'$exists':True,'$ne':[]},'call_behavior.number_used.telecom':'中国联通'},{'_id':0,'calls_overview':1,'sid':1})
call_log=list(call_log)
pri_tu(call_log)

# %%
SIDabba6b9f97ae30a9bcd0454233ebda3f
SID9d6e1137c54465a0452db3aa8066c257

# %%
call_log=db_conn.call_log.find({'sid':'SID9d6e1137c54465a0452db3aa8066c257'})
call_log=list(call_log)
pd_call=pd.DataFrame(x for x in call_log)

# %%
pd_call.loc[pd_call['call_tel'].values=='*******',:]
# Out:
#                             _id call_cost call_duration call_from call_method  \
# 148    5bbd58e89fcf60063e909173      0.00            50        阳江          主叫
# 168    5bbd58e89fcf60063e909170      0.00            20        阳江          主叫
# 187    5bbd58e89fcf60063e909171      0.00            26        阳江          主叫
# 192    5bbd58e89fcf60063e90918f      0.00            18        阳江          主叫
# 194    5bbd58e89fcf60063e90918e      0.00            52        阳江          主叫
# 196    5bbd58e89fcf60063e909184      0.00            29        阳江          主叫
# 198    5bbd58e89fcf60063e909182      0.00             5        阳江          主叫
# 199    5bbd58e89fcf60063e909190      0.00            28        阳江          主叫
# 225    5bbd58e89fcf60063e909183      0.00            12        阳江          主叫
# 227    5bbd58e89fcf60063e909193      0.00            29        阳江          主叫
# 240    5bbd58e89fcf60063e90919c      0.00            11        阳江          主叫
# 244    5bbd58e89fcf60063e909199      0.00            79        阳江          主叫
# 247    5bbd58e89fcf60063e909181      0.00             3        阳江          主叫
# 253    5bbd58e89fcf60063e909191      0.00            10        阳江          主叫
# 254    5bbd58e89fcf60063e909194      0.00             3        阳江          主叫
# 2232   5bbd58e99fcf60073e9216e3      0.00            26        阳江          主叫
# 2264   5bbd58e99fcf60073e9216e5      0.00            50        阳江          主叫
# 2392   5bbd58e99fcf60073e9216e2      0.00            20        阳江          主叫
# 2398   5bbd58e99fcf60073e921700      0.00            52        阳江          主叫
# 2399   5bbd58e99fcf60073e921702      0.00            28        阳江          主叫
# 2407   5bbd58e99fcf60073e9216f6      0.00            29        阳江          主叫
# 2408   5bbd58e99fcf60073e921703      0.00            10        阳江          主叫
# 2409   5bbd58e99fcf60073e921705      0.00            29        阳江          主叫
# 2411   5bbd58e99fcf60073e9216f3      0.00             3        阳江          主叫
# 2412   5bbd58e99fcf60073e92170e      0.00            11        阳江          主叫
# 2414   5bbd58e99fcf60073e92170b      0.00            79        阳江          主叫
# 2421   5bbd58e99fcf60073e921706      0.00             3        阳江          主叫
# 2429   5bbd58e99fcf60073e9216f4      0.00             5        阳江          主叫
# 2431   5bbd58e99fcf60073e921701      0.00            18        阳江          主叫
# 2433   5bbd58e99fcf60073e9216f5      0.00            12        阳江          主叫
# ...                         ...       ...           ...       ...         ...
# 13336  5bbd58ec9fcf60073e92282a      0.00             5        阳江          主叫
# 13337  5bbd58ec9fcf60073e92283c      0.00             3        阳江          主叫
# 13342  5bbd58ec9fcf60073e922837      0.00            18        阳江          主叫
# 13343  5bbd58ec9fcf60073e922838      0.00            28        阳江          主叫
# 13346  5bbd58ec9fcf60073e922819      0.00            26        阳江          主叫
# 13356  5bbd58ec9fcf60073e922829      0.00             3        阳江          主叫
# 13374  5bbd58ec9fcf60073e922818      0.00            20        阳江          主叫
# 13397  5bbd58ec9fcf60073e922841      0.00            79        阳江          主叫
# 13411  5bbd58ec9fcf60073e92282c      0.00            29        阳江          主叫
# 13428  5bbd58ec9fcf60073e922839      0.00            10        阳江          主叫
# 13432  5bbd58ec9fcf60073e922844      0.00            11        阳江          主叫
# 13435  5bbd58ec9fcf60073e92283b      0.00            29        阳江          主叫
# 13446  5bbd58ec9fcf60073e922836      0.00            52        阳江          主叫
# 13448  5bbd58ec9fcf60073e92281b      0.00            50        阳江          主叫
# 13457  5bbd58ec9fcf60073e92282b      0.00            12        阳江          主叫
# 15476  5bbd58ed9fcf60063e90b405      0.00            79        阳江          主叫
# 15520  5bbd58ed9fcf60063e90b3fa      0.00            52        阳江          主叫
# 15565  5bbd58ed9fcf60063e90b3ee      0.00             5        阳江          主叫
# 15611  5bbd58ed9fcf60063e90b400      0.00             3        阳江          主叫
# 15630  5bbd58ed9fcf60063e90b408      0.00            11        阳江          主叫
# 15649  5bbd58ed9fcf60063e90b3f0      0.00            29        阳江          主叫
# 15650  5bbd58ed9fcf60063e90b3ff      0.00            29        阳江          主叫
# 15740  5bbd58ed9fcf60063e90b3ed      0.00             3        阳江          主叫
# 15855  5bbd58ed9fcf60063e90b3dc      0.00            20        阳江          主叫
# 15857  5bbd58ed9fcf60063e90b3fb      0.00            18        阳江          主叫
# 15868  5bbd58ed9fcf60063e90b3df      0.00            50        阳江          主叫
# 15987  5bbd58ed9fcf60063e90b3fc      0.00            28        阳江          主叫
# 16018  5bbd58ed9fcf60063e90b3ef      0.00            12        阳江          主叫
# 16032  5bbd58ed9fcf60063e90b3dd      0.00            26        阳江          主叫
# 16033  5bbd58ed9fcf60063e90b3fd      0.00            10        阳江          主叫
#
#       call_tel   call_time call_to call_type   month  \
# 148    *******  1537804730            本地主叫本地  201809
# 168    *******  1537823730            本地主叫本地  201809
# 187    *******  1537806732            本地主叫本地  201809
# 192    *******  1537197623            本地主叫本地  201809
# 194    *******  1537240629            本地主叫本地  201809
# 196    *******  1537445110            本地主叫本地  201809
# 198    *******  1537523444            本地主叫本地  201809
# 199    *******  1537196845            本地主叫本地  201809
# 225    *******  1537523321            本地主叫本地  201809
# 227    *******  1537179300            本地主叫本地  201809
# 240    *******  1537070696            本地主叫本地  201809
# 244    *******  1537071571            本地主叫本地  201809
# 247    *******  1537524216            本地主叫本地  201809
# 253    *******  1537196242            本地主叫本地  201809
# 254    *******  1537178114            本地主叫本地  201809
# 2232   *******  1537806732            本地主叫本地  201809
# 2264   *******  1537804730            本地主叫本地  201809
# 2392   *******  1537823730            本地主叫本地  201809
# 2398   *******  1537240629            本地主叫本地  201809
# 2399   *******  1537196845            本地主叫本地  201809
# 2407   *******  1537445110            本地主叫本地  201809
# 2408   *******  1537196242            本地主叫本地  201809
# 2409   *******  1537179300            本地主叫本地  201809
# 2411   *******  1537524216            本地主叫本地  201809
# 2412   *******  1537070696            本地主叫本地  201809
# 2414   *******  1537071571            本地主叫本地  201809
# 2421   *******  1537178114            本地主叫本地  201809
# 2429   *******  1537523444            本地主叫本地  201809
# 2431   *******  1537197623            本地主叫本地  201809
# 2433   *******  1537523321            本地主叫本地  201809
# ...        ...         ...     ...       ...     ...
# 13336  *******  1537523444            本地主叫本地  201809
# 13337  *******  1537178114            本地主叫本地  201809
# 13342  *******  1537197623            本地主叫本地  201809
# 13343  *******  1537196845            本地主叫本地  201809
# 13346  *******  1537806732            本地主叫本地  201809
# 13356  *******  1537524216            本地主叫本地  201809
# 13374  *******  1537823730            本地主叫本地  201809
# 13397  *******  1537071571            本地主叫本地  201809
# 13411  *******  1537445110            本地主叫本地  201809
# 13428  *******  1537196242            本地主叫本地  201809
# 13432  *******  1537070696            本地主叫本地  201809
# 13435  *******  1537179300            本地主叫本地  201809
# 13446  *******  1537240629            本地主叫本地  201809
# 13448  *******  1537804730            本地主叫本地  201809
# 13457  *******  1537523321            本地主叫本地  201809
# 15476  *******  1537071571            本地主叫本地  201809
# 15520  *******  1537240629            本地主叫本地  201809
# 15565  *******  1537523444            本地主叫本地  201809
# 15611  *******  1537178114            本地主叫本地  201809
# 15630  *******  1537070696            本地主叫本地  201809
# 15649  *******  1537445110            本地主叫本地  201809
# 15650  *******  1537179300            本地主叫本地  201809
# 15740  *******  1537524216            本地主叫本地  201809
# 15855  *******  1537823730            本地主叫本地  201809
# 15857  *******  1537197623            本地主叫本地  201809
# 15868  *******  1537804730            本地主叫本地  201809
# 15987  *******  1537196845            本地主叫本地  201809
# 16018  *******  1537523321            本地主叫本地  201809
# 16032  *******  1537806732            本地主叫本地  201809
# 16033  *******  1537196242            本地主叫本地  201809
#
#                                        sid          tel  update_time
# 148    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 168    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 187    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 192    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 194    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 196    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 198    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 199    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 225    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 227    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 240    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 244    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 247    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 253    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 254    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2232   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2264   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2392   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2398   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2399   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2407   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2408   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2409   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2411   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2412   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2414   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2421   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2429   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2431   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2433   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# ...                                    ...          ...          ...
# 13336  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13337  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13342  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13343  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13346  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13356  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13374  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13397  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13411  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13428  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13432  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13435  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13446  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13448  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13457  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 15476  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15520  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15565  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15611  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15630  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15649  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15650  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15740  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15855  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15857  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15868  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15987  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 16018  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 16032  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 16033  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
#
# [120 rows x 13 columns]

# %%
def phone_format(tel):
    """
    用于处理各种格式手机号/服务号/座机号
    return:
        tel: str, The formated tel

    已处理格式:
    1795109312155980 # 17951-09312155980 17951 + 区号 + 座机号
    125930085292050000 # 12593-00852-92050000 12593 + 区号 + 座机号
    12583118901128803 # 125831-18901128803 125831 + 手机号
    125900400493018750074791 # 1259004004+930+18750074791  1259004004 + 930(积分编码) + 工号(手机号)

    01068260630 # 010-68260630 区号（3位） + 座机号
    087168260630 # 0871-68260630 区号（4位） + 座机号
    01012599 # 010-12599 区号（3位） + 服务号
    051512599 # 0515-12599 区号（4位） + 服务号
    095510 # 0-95510 '0' + 服务号
    018901128803 '0' + 手机号
    0018901128803 '00' + 手机号
    008617701020875 '0086' + 手机号

    1081190501 # (0)10-81190501 区号去"0"
    769125909888037 # (0)769-12590-9888037 区号去"0"
    1011895544 # (0)10-11895544 暂未确认，不做处理
    7694006595555 # (0)769-4006595555 区号去"0"

    862039195228 # 86-020-39195228 86 + 区号（3位） + 座机号
    8675782220098 # 86-0757-82220098 86 + 区号（4位） + 座机号
    8618984153165 # 86-18984153165 86 + 手机号
    864008009888 # 86-4008009888 86 + 400服务号

    68260630 # 座机号
    18901128803 # 手机号
    4008009888 # 全国公共号码
    1010xxxx # 新全国公共号码

    (0995)18699548143 (区号)手机号
    (010)15001127901 (区号)手机号
    (010)01010086  (区号) + 区号 + 全国号码
    (010)95559 (区号) + 全国号码
    (0891)4008089188 (区号) + 全国号码
    (020)4008101688 (区号) + 全国号码

    '4006405258 ' # 各种格式带' '情况
    09968778888@ims.xj
    04008208788 # 0-400-8208788 0+全国服务号码

    """
    import re
    try:
        s = re.sub(r'[^\d\(\)\*]', '', tel)
    except:
        s = tel
    if re.match(r'^17951|12593', s):
        s = s[5:]
    if re.match(r'^125831', s):
        s = s[6:]
    if re.match(r'^1259004004', s):
        s = s[-11:]
    if re.match(r'^\(',s):
        area_code, tel = re.match(r'\((.*?)\)(.*)',s).groups()
        if area_code == tel[:len(area_code)]:
            tel = tel[len(area_code):]
        if re.match(r'^0(10|2[\d])([2-8][\d]{7}|96[\d]{3,11}|95[\d]{3,14}|1010[\d]{4}|1[\d]{4})$', area_code+tel):
            s = area_code+tel
        elif re.match(r'^0[3-9][\d]{2}([2-8][\d]{6,7}|96[\d]{3,10}|95[\d]{3,14}|1[\d]{4})$',area_code+tel):
            s = area_code+tel
        else:
            s = tel
    if re.match(r'^0',s):
        if re.match(r'^0(10|2[\d])([2-8][\d]{7}|96[\d]{3,11}|95[\d]{3,14}|1010[\d]{4}|1[\d]{4})$',s):
            s = s[:3] + '-' + s[3:]
        elif re.match(r'^0(400|800|1010)', s):
            s = s[1:]
        elif re.match(r'^0[3-9][\d]{2}([2-8][\d]{6,7}|96[\d]{3,10}|95[\d]{3,14}|1[\d]{4})$',s):
            s = s[:4] + '-' + s[4:]
        elif re.match(r'^00852\d{8}',s):
            s = s[:5] + '-' + s[5:]
        elif re.match(r'^(0|00|0086)(1[358]\d{9}|17[0135678]\d{8})$',s):
            s = s[-11:]
        elif re.match(r'^(0|00)[\d]{5}$',s):
            s = s[1:]
    if re.match(r'^(86|(10|2[\d])(400|800|1010|12590)\d+)',s):
        s = s[2:]
    if re.match(r'^(10|2[\d])([2-8][\d]{7}|96[\d]{3,11}|95[\d]{3,14})$',s):
        s = '0' + s[:2] + '-' + s[2:]
    elif re.match(r'^(400|800|1010)',s):
        s = s
    elif re.match(r'^[3-9][\d]{2}(400|800|1010|12590)\d+$',s):
        s = s[3:]
    elif re.match(r'^[3-9][\d]{2}([2-8][\d]{6,7}|96[\d]{3,10}|95[\d]{3,14})$',s):
        s = '0' + s[:3] + '-' + s[3:]
    return s

# %%
pd_call['call_tel']=pd_call['call_tel'].apply(lambda x:phone_format(x))
pd_call.loc[pd_call['call_tel'].values=='*******',:]
# Out:
#                             _id call_cost call_duration call_from call_method  \
# 148    5bbd58e89fcf60063e909173      0.00            50        阳江          主叫
# 168    5bbd58e89fcf60063e909170      0.00            20        阳江          主叫
# 187    5bbd58e89fcf60063e909171      0.00            26        阳江          主叫
# 192    5bbd58e89fcf60063e90918f      0.00            18        阳江          主叫
# 194    5bbd58e89fcf60063e90918e      0.00            52        阳江          主叫
# 196    5bbd58e89fcf60063e909184      0.00            29        阳江          主叫
# 198    5bbd58e89fcf60063e909182      0.00             5        阳江          主叫
# 199    5bbd58e89fcf60063e909190      0.00            28        阳江          主叫
# 225    5bbd58e89fcf60063e909183      0.00            12        阳江          主叫
# 227    5bbd58e89fcf60063e909193      0.00            29        阳江          主叫
# 240    5bbd58e89fcf60063e90919c      0.00            11        阳江          主叫
# 244    5bbd58e89fcf60063e909199      0.00            79        阳江          主叫
# 247    5bbd58e89fcf60063e909181      0.00             3        阳江          主叫
# 253    5bbd58e89fcf60063e909191      0.00            10        阳江          主叫
# 254    5bbd58e89fcf60063e909194      0.00             3        阳江          主叫
# 2232   5bbd58e99fcf60073e9216e3      0.00            26        阳江          主叫
# 2264   5bbd58e99fcf60073e9216e5      0.00            50        阳江          主叫
# 2392   5bbd58e99fcf60073e9216e2      0.00            20        阳江          主叫
# 2398   5bbd58e99fcf60073e921700      0.00            52        阳江          主叫
# 2399   5bbd58e99fcf60073e921702      0.00            28        阳江          主叫
# 2407   5bbd58e99fcf60073e9216f6      0.00            29        阳江          主叫
# 2408   5bbd58e99fcf60073e921703      0.00            10        阳江          主叫
# 2409   5bbd58e99fcf60073e921705      0.00            29        阳江          主叫
# 2411   5bbd58e99fcf60073e9216f3      0.00             3        阳江          主叫
# 2412   5bbd58e99fcf60073e92170e      0.00            11        阳江          主叫
# 2414   5bbd58e99fcf60073e92170b      0.00            79        阳江          主叫
# 2421   5bbd58e99fcf60073e921706      0.00             3        阳江          主叫
# 2429   5bbd58e99fcf60073e9216f4      0.00             5        阳江          主叫
# 2431   5bbd58e99fcf60073e921701      0.00            18        阳江          主叫
# 2433   5bbd58e99fcf60073e9216f5      0.00            12        阳江          主叫
# ...                         ...       ...           ...       ...         ...
# 13336  5bbd58ec9fcf60073e92282a      0.00             5        阳江          主叫
# 13337  5bbd58ec9fcf60073e92283c      0.00             3        阳江          主叫
# 13342  5bbd58ec9fcf60073e922837      0.00            18        阳江          主叫
# 13343  5bbd58ec9fcf60073e922838      0.00            28        阳江          主叫
# 13346  5bbd58ec9fcf60073e922819      0.00            26        阳江          主叫
# 13356  5bbd58ec9fcf60073e922829      0.00             3        阳江          主叫
# 13374  5bbd58ec9fcf60073e922818      0.00            20        阳江          主叫
# 13397  5bbd58ec9fcf60073e922841      0.00            79        阳江          主叫
# 13411  5bbd58ec9fcf60073e92282c      0.00            29        阳江          主叫
# 13428  5bbd58ec9fcf60073e922839      0.00            10        阳江          主叫
# 13432  5bbd58ec9fcf60073e922844      0.00            11        阳江          主叫
# 13435  5bbd58ec9fcf60073e92283b      0.00            29        阳江          主叫
# 13446  5bbd58ec9fcf60073e922836      0.00            52        阳江          主叫
# 13448  5bbd58ec9fcf60073e92281b      0.00            50        阳江          主叫
# 13457  5bbd58ec9fcf60073e92282b      0.00            12        阳江          主叫
# 15476  5bbd58ed9fcf60063e90b405      0.00            79        阳江          主叫
# 15520  5bbd58ed9fcf60063e90b3fa      0.00            52        阳江          主叫
# 15565  5bbd58ed9fcf60063e90b3ee      0.00             5        阳江          主叫
# 15611  5bbd58ed9fcf60063e90b400      0.00             3        阳江          主叫
# 15630  5bbd58ed9fcf60063e90b408      0.00            11        阳江          主叫
# 15649  5bbd58ed9fcf60063e90b3f0      0.00            29        阳江          主叫
# 15650  5bbd58ed9fcf60063e90b3ff      0.00            29        阳江          主叫
# 15740  5bbd58ed9fcf60063e90b3ed      0.00             3        阳江          主叫
# 15855  5bbd58ed9fcf60063e90b3dc      0.00            20        阳江          主叫
# 15857  5bbd58ed9fcf60063e90b3fb      0.00            18        阳江          主叫
# 15868  5bbd58ed9fcf60063e90b3df      0.00            50        阳江          主叫
# 15987  5bbd58ed9fcf60063e90b3fc      0.00            28        阳江          主叫
# 16018  5bbd58ed9fcf60063e90b3ef      0.00            12        阳江          主叫
# 16032  5bbd58ed9fcf60063e90b3dd      0.00            26        阳江          主叫
# 16033  5bbd58ed9fcf60063e90b3fd      0.00            10        阳江          主叫
#
#       call_tel   call_time call_to call_type   month  \
# 148    *******  1537804730            本地主叫本地  201809
# 168    *******  1537823730            本地主叫本地  201809
# 187    *******  1537806732            本地主叫本地  201809
# 192    *******  1537197623            本地主叫本地  201809
# 194    *******  1537240629            本地主叫本地  201809
# 196    *******  1537445110            本地主叫本地  201809
# 198    *******  1537523444            本地主叫本地  201809
# 199    *******  1537196845            本地主叫本地  201809
# 225    *******  1537523321            本地主叫本地  201809
# 227    *******  1537179300            本地主叫本地  201809
# 240    *******  1537070696            本地主叫本地  201809
# 244    *******  1537071571            本地主叫本地  201809
# 247    *******  1537524216            本地主叫本地  201809
# 253    *******  1537196242            本地主叫本地  201809
# 254    *******  1537178114            本地主叫本地  201809
# 2232   *******  1537806732            本地主叫本地  201809
# 2264   *******  1537804730            本地主叫本地  201809
# 2392   *******  1537823730            本地主叫本地  201809
# 2398   *******  1537240629            本地主叫本地  201809
# 2399   *******  1537196845            本地主叫本地  201809
# 2407   *******  1537445110            本地主叫本地  201809
# 2408   *******  1537196242            本地主叫本地  201809
# 2409   *******  1537179300            本地主叫本地  201809
# 2411   *******  1537524216            本地主叫本地  201809
# 2412   *******  1537070696            本地主叫本地  201809
# 2414   *******  1537071571            本地主叫本地  201809
# 2421   *******  1537178114            本地主叫本地  201809
# 2429   *******  1537523444            本地主叫本地  201809
# 2431   *******  1537197623            本地主叫本地  201809
# 2433   *******  1537523321            本地主叫本地  201809
# ...        ...         ...     ...       ...     ...
# 13336  *******  1537523444            本地主叫本地  201809
# 13337  *******  1537178114            本地主叫本地  201809
# 13342  *******  1537197623            本地主叫本地  201809
# 13343  *******  1537196845            本地主叫本地  201809
# 13346  *******  1537806732            本地主叫本地  201809
# 13356  *******  1537524216            本地主叫本地  201809
# 13374  *******  1537823730            本地主叫本地  201809
# 13397  *******  1537071571            本地主叫本地  201809
# 13411  *******  1537445110            本地主叫本地  201809
# 13428  *******  1537196242            本地主叫本地  201809
# 13432  *******  1537070696            本地主叫本地  201809
# 13435  *******  1537179300            本地主叫本地  201809
# 13446  *******  1537240629            本地主叫本地  201809
# 13448  *******  1537804730            本地主叫本地  201809
# 13457  *******  1537523321            本地主叫本地  201809
# 15476  *******  1537071571            本地主叫本地  201809
# 15520  *******  1537240629            本地主叫本地  201809
# 15565  *******  1537523444            本地主叫本地  201809
# 15611  *******  1537178114            本地主叫本地  201809
# 15630  *******  1537070696            本地主叫本地  201809
# 15649  *******  1537445110            本地主叫本地  201809
# 15650  *******  1537179300            本地主叫本地  201809
# 15740  *******  1537524216            本地主叫本地  201809
# 15855  *******  1537823730            本地主叫本地  201809
# 15857  *******  1537197623            本地主叫本地  201809
# 15868  *******  1537804730            本地主叫本地  201809
# 15987  *******  1537196845            本地主叫本地  201809
# 16018  *******  1537523321            本地主叫本地  201809
# 16032  *******  1537806732            本地主叫本地  201809
# 16033  *******  1537196242            本地主叫本地  201809
#
#                                        sid          tel  update_time
# 148    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 168    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 187    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 192    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 194    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 196    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 198    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 199    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 225    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 227    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 240    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 244    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 247    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 253    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 254    SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2232   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2264   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2392   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2398   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2399   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2407   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2408   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2409   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2411   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2412   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2414   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2421   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2429   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2431   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# 2433   SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135720
# ...                                    ...          ...          ...
# 13336  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13337  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13342  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13343  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13346  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13356  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13374  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13397  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13411  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13428  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13432  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13435  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13446  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13448  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 13457  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135723
# 15476  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15520  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15565  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15611  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15630  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15649  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15650  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15740  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15855  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15857  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15868  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 15987  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 16018  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 16032  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
# 16033  SID9d6e1137c54465a0452db3aa8066c257  18475154962   1539135724
#
# [120 rows x 13 columns]

# %%
res = call_log
seen = set()  
tel_data = [(x.get("call_tel"), x.get("call_from","")) for x in res if not (x.get("call_tel") in seen or seen.add(x.get("call_tel")))]

# %%
for x in tel_data:
    if x[0]=='*******':
        print(x)
# Out:
# ('*******', '阳江')

# %%
def format_tel_data(tel_data):
    import re
    value = re.compile('[1-9]\d*')
    for tel_tuple in tel_data:
        tel=tel_tuple[0].replace('*','').replace(' ','')
        result = value.findall(tel)
        if not result:
            tel_data.remove(tel_tuple)
    return tel_data

# %%
format_tel_data([('****', '阳江')])
# Out:
# []

# %%
tmp=format_tel_data(tel_data)

# %%
len(tel_data)
# Out:
# 1161

# %%
for x in tmp:
    if x[0]=='*******':
        print(x)

# %%
tel_data
# Out:
# [('57456633895', '阳江'),
#  ('18844057459', '阳江'),
#  ('57487374706', '阳江'),
#  ('157********', '阳江'),
#  ('95795416', '阳江'),
#  ('18948524238', '阳江'),
#  ('95210699', '阳江'),
#  ('17759374318', '阳江'),
#  ('15718299845', '阳江'),
#  ('18457360710', '阳江'),
#  ('18595746794', '阳江'),
#  ('136********', '阳江'),
#  ('00863723814647', '阳江'),
#  ('37163331392', '阳江'),
#  ('95030', '阳江'),
#  ('00865377710584', '阳江'),
#  ('17042722116', '阳江'),
#  ('0086662125400039510211', '阳江'),
#  ('18558917821', '阳江'),
#  ('00867902105462', '阳江'),
#  ('13078316736', '阳江'),
#  ('13867146374', '阳江'),
#  ('15180475737', '阳江'),
#  ('13600973643', '阳江'),
#  ('51081995142', '阳江'),
#  ('19955472188', '阳江'),
#  ('135********', '阳江'),
#  ('00864578926263', '阳江'),
#  ('18067787850', '阳江'),
#  ('51081995485', '阳江'),
#  ('00867372939410', '阳江'),
#  ('00862887655714', '阳江'),
#  ('9516724219', '阳江'),
#  ('73182021161', '阳江'),
#  ('00861058491398', '阳江'),
#  ('139********', '阳江'),
#  ('95795406', '阳江'),
#  ('00861053560390', '阳江'),
#  ('00865366852889', '阳江'),
#  ('18058588454', '阳江'),
#  ('13542657952', '阳江'),
#  ('18758272351', '阳江'),
#  ('13378839633', '阳江'),
#  ('14700559168', '阳江'),
#  ('0755********', '阳江'),
#  ('76933667687', '阳江'),
#  ('13059866302', '阳江'),
#  ('00867372939405', '阳江'),
#  ('13725617530', '阳江'),
#  ('57482539162', '阳江'),
#  ('00862386723885', '阳江'),
#  ('13359469721', '阳江'),
#  ('37156071101', '阳江'),
#  ('166********', '阳江'),
#  ('00862887546343', '阳江'),
#  ('13794790385', '阳江'),
#  ('00862022954793', '阳江'),
#  ('131********', '阳江'),
#  ('18316431897', '阳江'),
#  ('138********', '阳江'),
#  ('180********', '阳江'),
#  ('00867372939416', '阳江'),
#  ('18969042250', '阳江'),
#  ('95054714', '阳江'),
#  ('17758200097', '阳江'),
#  ('00864596385112', '阳江'),
#  ('37122355392', '阳江'),
#  ('51081994702', '阳江'),
#  ('189********', '阳江'),
#  ('186********', '阳江'),
#  ('15337192904', '阳江'),
#  ('57128063539', '阳江'),
#  ('87168623158', '阳江'),
#  ('137********', '阳江'),
#  ('37156020537', '阳江'),
#  ('00864578926490', '阳江'),
#  ('008695223441', '阳江'),
#  ('18086032712', '阳江'),
#  ('37188957440', '阳江'),
#  ('15079136401', '阳江'),
#  ('18962135743', '阳江'),
#  ('00862160554896', '阳江'),
#  ('15899670554', '阳江'),
#  ('00862887659483', '阳江'),
#  ('00862883118547', '阳江'),
#  ('18922465973', '阳江'),
#  ('00862863206825', '阳江'),
#  ('00864127183029', '阳江'),
#  ('00861086210574', '阳江'),
#  ('95054719', '阳江'),
#  ('18200818421', '阳江'),
#  ('00867902105428', '阳江'),
#  ('00867143869187', '阳江'),
#  ('00861052783020', '阳江'),
#  ('55169137809', '阳江'),
#  ('57157178237', '阳江'),
#  ('00863723824742', '阳江'),
#  ('57487153479', '阳江'),
#  ('17156998511', '阳江'),
#  ('17353712185', '阳江'),
#  ('57156063015', '阳江'),
#  ('151********', '阳江'),
#  ('00861052783038', '阳江'),
#  ('57428916795', '阳江'),
#  ('00864127186439', '阳江'),
#  ('00862887541472', '阳江'),
#  ('00862968285734', '阳江'),
#  ('00865532164410', '阳江'),
#  ('57128203056', '阳江'),
#  ('18469844106', '阳江'),
#  ('00866627823810', '阳江'),
#  ('73152653510', '阳江'),
#  ('40********', '阳江'),
#  ('57156102306', '阳江'),
#  ('53158627035', '阳江'),
#  ('57156079534', '阳江'),
#  ('00868383631579', '阳江'),
#  ('00865532617801', '阳江'),
#  ('4009699559', '阳江'),
#  ('13794767242', '阳江'),
#  ('95054423', '阳江'),
#  ('00862861456310', '阳江'),
#  ('87168118487', '阳江'),
#  ('57156065571', '阳江'),
#  ('133********', '阳江'),
#  ('00865372273158', '阳江'),
#  ('066********', '阳江'),
#  ('17171175791', '阳江'),
#  ('17301360195', '阳江'),
#  ('55165292692', '阳江'),
#  ('15710287064', '阳江'),
#  ('00866627823626', '阳江'),
#  ('15356034015', '阳江'),
#  ('18782910904', '阳江'),
#  ('00866627892179', '阳江'),
#  ('15819124360', '阳江'),
#  ('18319919896', '阳江'),
#  ('00862889362014', '阳江'),
#  ('13164963854', '阳江'),
#  ('13664966584', '阳江'),
#  ('17044028570', '阳江'),
#  ('57459985518', '阳江'),
#  ('952067', '阳江'),
#  ('159********', '阳江'),
#  ('19967476717', '阳江'),
#  ('13162212428', '阳江'),
#  ('17720128015', '阳江'),
#  ('57156109739', '阳江'),
#  ('57128203050', '阳江'),
#  ('95054141', '阳江'),
#  ('18890201061', '阳江'),
#  ('00864127185536', '阳江'),
#  ('57459985509', '阳江'),
#  ('00867686662124', '阳江'),
#  ('13004982661', '阳江'),
#  ('00869312122187', '阳江'),
#  ('57487634796', '阳江'),
#  ('13318558908', '阳江'),
#  ('15393806627', '阳江'),
#  ('18163382455', '阳江'),
#  ('15869645326', '阳江'),
#  ('13106382265', '阳江'),
#  ('00865532672545', '阳江'),
#  ('18368208468', '阳江'),
#  ('18456415430', '阳江'),
#  ('13738037047', '阳江'),
#  ('00862151915015', '阳江'),
#  ('18668596014', '阳江'),
#  ('18844181359', '阳江'),
#  ('18672711729', '阳江'),
#  ('57487195994', '阳江'),
#  ('13017739693', '阳江'),
#  ('13736040851', '阳江'),
#  ('008695714059', '阳江'),
#  ('37156609053', '阳江'),
#  ('00865356845334', '阳江'),
#  ('13360064234', '阳江'),
#  ('00868392307865', '阳江'),
#  ('13706687343', '阳江'),
#  ('00862860115927', '阳江'),
#  ('13183867630', '阳江'),
#  ('18751927548', '阳江'),
#  ('15681383931', '阳江'),
#  ('17521633531', '阳江'),
#  ('13330483034', '阳江'),
#  ('00861052591176', '阳江'),
#  ('18357832765', '阳江'),
#  ('13705876275', '阳江'),
#  ('95219912', '阳江'),
#  ('57982555301', '阳江'),
#  ('57982555065', '阳江'),
#  ('18318246996', '阳江'),
#  ('13117945017', '阳江'),
#  ('00861052594001', '阳江'),
#  ('008666********', '阳江'),
#  ('17855260169', '阳江'),
#  ('00868318786003', '阳江'),
#  ('008695714076', '阳江'),
#  ('008695714005', '阳江'),
#  ('00862151915014', '阳江'),
#  ('13075725710', '阳江'),
#  ('15859631326', '阳江'),
#  ('79182050308', '阳江'),
#  ('008695714031', '阳江'),
#  ('18637078921', '阳江'),
#  ('18968044365', '阳江'),
#  ('15356482362', '阳江'),
#  ('18858010718', '阳江'),
#  ('00861053978318', '阳江'),
#  ('13004820517', '阳江'),
#  ('00865356023482', '阳江'),
#  ('13926012213', '阳江'),
#  ('00865532621593', '阳江'),
#  ('18058314320', '阳江'),
#  ('13062179310', '阳江'),
#  ('17040741063', '阳江'),
#  ('95206741', '阳江'),
#  ('57126208060', '阳江'),
#  ('13736787604', '阳江'),
#  ('008695714158', '阳江'),
#  ('18324251893', '阳江'),
#  ('15779789771', '阳江'),
#  ('00867902106435', '阳江'),
#  ('13837059787', '阳江'),
#  ('15685445346', '阳江'),
#  ('75561802288', '阳江'),
#  ('00867902105267', '阳江'),
#  ('00861053153912', '阳江'),
#  ('13362499695', '阳江'),
#  ('79182222190', '阳江'),
#  ('15908859844', '阳江'),
#  ('37163334105', '阳江'),
#  ('18062623867', '阳江'),
#  ('15658164879', '阳江'),
#  ('00868318757060', '阳江'),
#  ('00861052593198', '阳江'),
#  ('13758795595', '阳江'),
#  ('18142080148', '阳江'),
#  ('18967071985', '阳江'),
#  ('00865356843749', '阳江'),
#  ('00861053978191', '阳江'),
#  ('51668923920', '阳江'),
#  ('57725694555', '阳江'),
#  ('00861053951003', '阳江'),
#  ('13635994048', '阳江'),
#  ('18650827351', '阳江'),
#  ('15288121880', '阳江'),
#  ('9521355', '阳江'),
#  ('13587489874', '阳江'),
#  ('17869449796', '阳江'),
#  ('57427877933', '阳江'),
#  ('57483016726', '阳江'),
#  ('13587998246', '阳江'),
#  ('51081994001', '阳江'),
#  ('00864578925526', '阳江'),
#  ('00865532612720', '阳江'),
#  ('15585390441', '阳江'),
#  ('15219358936', '阳江'),
#  ('13393828768', '阳江'),
#  ('00868396026055', '阳江'),
#  ('13645776642', '阳江'),
#  ('18157872161', '阳江'),
#  ('00862151529902', '阳江'),
#  ('18165689643', '阳江'),
#  ('13389003865', '阳江'),
#  ('95054894', '阳江'),
#  ('13179620392', '阳江'),
#  ('37156611338', '阳江'),
#  ('057459985497', '阳江'),
#  ('13967083593', '阳江'),
#  ('15555674777', '阳江'),
#  ('13255613268', '阳江'),
#  ('00862151915001', '阳江'),
#  ('13385840125', '阳江'),
#  ('57459985497', '阳江'),
#  ('17318331899', '阳江'),
#  ('13291968802', '阳江'),
#  ('15168006052', '阳江'),
#  ('17171321200', '阳江'),
#  ('13042407158', '阳江'),
#  ('87168623278', '阳江'),
#  ('15372835592', '阳江'),
#  ('17800232092', '阳江'),
#  ('13559300172', '阳江'),
#  ('13515069713', '阳江'),
#  ('134********', '阳江'),
#  ('18728168398', '阳江'),
#  ('57487013148', '阳江'),
#  ('00862151915003', '阳江'),
#  ('95054914', '阳江'),
#  ('18359275697', '阳江'),
#  ('57455864886', '阳江'),
#  ('13325970033', '阳江'),
#  ('15045156480', '阳江'),
#  ('18165689645', '阳江'),
#  ('9506512', '阳江'),
#  ('57483538870', '阳江'),
#  ('18958813170', '阳江'),
#  ('17858917045', '阳江'),
#  ('00865532612987', '阳江'),
#  ('15347171439', '阳江'),
#  ('18388856497', '阳江'),
#  ('37163333451', '阳江'),
#  ('13093507400', '阳江'),
#  ('18037755410', '阳江'),
#  ('00868387108362', '阳江'),
#  ('13460865226', '阳江'),
#  ('15868097583', '阳江'),
#  ('13905785740', '阳江'),
#  ('15806011613', '阳江'),
#  ('18210560097', '阳江'),
#  ('00862887714862', '阳江'),
#  ('00861083885692', '阳江'),
#  ('13559300375', '阳江'),
#  ('18756416475', '阳江'),
#  ('18675784195', '阳江'),
#  ('75561108867', '阳江'),
#  ('18680498817', '阳江'),
#  ('17364229072', '阳江'),
#  ('13030656776', '阳江'),
#  ('13376851467', '阳江'),
#  ('15655411761', '阳江'),
#  ('17043036460', '阳江'),
#  ('13664432659', '阳江'),
#  ('18756945376', '阳江'),
#  ('53158030947', '阳江'),
#  ('57156560888', '阳江'),
#  ('13587490864', '阳江'),
#  ('13567781247', '阳江'),
#  ('13712334985', '阳江'),
#  ('18292461943', '阳江'),
#  ('18905094688', '阳江'),
#  ('13276722960', '阳江'),
#  ('15126450107', '阳江'),
#  ('57156000797', '阳江'),
#  ('13291933562', '阳江'),
#  ('00868386383033', '阳江'),
#  ('13075725879', '阳江'),
#  ('57982555076', '阳江'),
#  ('19906522085', '阳江'),
#  ('13352882685', '阳江'),
#  ('15813075557', '阳江'),
#  ('87168118424', '阳江'),
#  ('17199537180', '阳江'),
#  ('18606081172', '阳江'),
#  ('87168623354', '阳江'),
#  ('13158354156', '阳江'),
#  ('15658218053', '阳江'),
#  ('17155814493', '阳江'),
#  ('15680271857', '阳江'),
#  ('13117212721', '阳江'),
#  ('13728381436', '阳江'),
#  ('13291963725', '阳江'),
#  ('37156078052', '阳江'),
#  ('18002747362', '阳江'),
#  ('37163330471', '阳江'),
#  ('18988336280', '阳江'),
#  ('17669457950', '阳江'),
#  ('00862887547951', '阳江'),
#  ('17165871113', '阳江'),
#  ('00862886336345', '阳江'),
#  ('95054143', '阳江'),
#  ('57488302183', '阳江'),
#  ('15557000381', '阳江'),
#  ('18250929107', '阳江'),
#  ('15381585636', '阳江'),
#  ('13566147371', '阳江'),
#  ('13409777025', '阳江'),
#  ('17863288492', '阳江'),
#  ('00865782977147', '阳江'),
#  ('95054545', '阳江'),
#  ('18061678118', '阳江'),
#  ('53158673457', '阳江'),
#  ('00864578926155', '阳江'),
#  ('13030953882', '阳江'),
#  ('15142448409', '阳江'),
#  ('18511461551', '阳江'),
#  ('15974192142', '阳江'),
#  ('57982908286', '阳江'),
#  ('00861052591189', '阳江'),
#  ('15258467812', '阳江'),
#  ('15356262137', '阳江'),
#  ('95210333', '阳江'),
#  ('00866628844118', '阳江'),
#  ('95054641', '阳江'),
#  ('06627892179', '阳江'),
#  ('17767289180', '阳江'),
#  ('00868396057324', '阳江'),
#  ('00864578925293', '阳江'),
#  ('76988032174', '阳江'),
#  ('7823626', '阳江'),
#  ('00865522574775', '阳江'),
#  ('15219341727', '阳江'),
#  ('00861053876522', '阳江'),
#  ('15305905126', '阳江'),
#  ('57157110114', '阳江'),
#  ('57487407859', '阳江'),
#  ('17819456497', '阳江'),
#  ('37960674410', '阳江'),
#  ('00861053155921', '阳江'),
#  ('00865507125080', '阳江'),
#  ('17767374689', '阳江'),
#  ('00867685892381', '阳江'),
#  ('00862938051667', '阳江'),
#  ('85188255766', '阳江'),
#  ('17199537823', '阳江'),
#  ('85188353966', '阳江'),
#  ('17042719687', '阳江'),
#  ('00862886336082', '阳江'),
#  ('15738075279', '阳江'),
#  ('00861053153913', '阳江'),
#  ('13685090745', '阳江'),
#  ('00862886336333', '阳江'),
#  ('00868387108682', '阳江'),
#  ('13015899360', '阳江'),
#  ('75536568938', '阳江'),
#  ('18595126948', '阳江'),
#  ('57982292777', '阳江'),
#  ('18372537095', '阳江'),
#  ('51780854293', '阳江'),
#  ('57128168199', '阳江'),
#  ('51484694754', '阳江'),
#  ('00865532617495', '阳江'),
#  ('00862827290531', '阳江'),
#  ('57156390273', '阳江'),
#  ('17767374651', '阳江'),
#  ('00865782263806', '阳江'),
#  ('57185456309', '阳江'),
#  ('18072038880', '阳江'),
#  ('15758404189', '阳江'),
#  ('17301984055', '阳江'),
#  ('51080574168', '阳江'),
#  ('57488361691', '阳江'),
#  ('00861053172960', '阳江'),
#  ('19967467396', '阳江'),
#  ('75561974295', '阳江'),
#  ('15397065308', '阳江'),
#  ('00865782111351', '阳江'),
#  ('75561108785', '阳江'),
#  ('00864127171939', '阳江'),
#  ('57486681615', '阳江'),
#  ('00865532617466', '阳江'),
#  ('00862887771174', '阳江'),
#  ('00864127172240', '阳江'),
#  ('75536555788', '阳江'),
#  ('18850675024', '阳江'),
#  ('17706735249', '阳江'),
#  ('18706059824', '阳江'),
#  ('00864127171355', '阳江'),
#  ('13380745320', '阳江'),
#  ('57156317263', '阳江'),
#  ('15925647644', '阳江'),
#  ('00862552298471', '阳江'),
#  ('00867962133496', '阳江'),
#  ('10086', '阳江'),
#  ('75536555786', '阳江'),
#  ('00861095568', '阳江'),
#  ('00862886336178', '阳江'),
#  ('00865782967565', '阳江'),
#  ('00864127171651', '阳江'),
#  ('57156390268', '阳江'),
#  ('75536555785', '阳江'),
#  ('75566871658', '阳江'),
#  ('00868315958490', '阳江'),
#  ('13063884993', '阳江'),
#  ('00864127173040', '阳江'),
#  ('18868797385', '阳江'),
#  ('37156062663', '阳江'),
#  ('15106954138', '阳江'),
#  ('00864642948624', '阳江'),
#  ('4006700188', '阳江'),
#  ('4001028800', '阳江'),
#  ('15605263577', '阳江'),
#  ('17573415266', '阳江'),
#  ('00866628844114', '阳江'),
#  ('15659531553', '阳江'),
#  ('13221967035', '阳江'),
#  ('00861050894064', '阳江'),
#  ('15220192316', '阳江'),
#  ('37153308262', '阳江'),
#  ('75536555784', '阳江'),
#  ('53158030490', '阳江'),
#  ('00864578925931', '阳江'),
#  ('00867303079322', '阳江'),
#  ('00868175234461', '阳江'),
#  ('73188213637', '阳江'),
#  ('15347689200', '阳江'),
#  ('18028093492', '阳江'),
#  ('17156955187', '阳江'),
#  ('13357049521', '阳江'),
#  ('13020902392', '阳江'),
#  ('95217138', '阳江'),
#  ('00862151874847', '阳江'),
#  ('18666703709', '阳江'),
#  ('008695714142', '阳江'),
#  ('13217103966', '阳江'),
#  ('85188309380', '阳江'),
#  ('13291508256', '阳江'),
#  ('13018903619', '阳江'),
#  ('00862869331701', '阳江'),
#  ('00865532621970', '阳江'),
#  ('18957440510', '阳江'),
#  ('51081995466', '阳江'),
#  ('00862887534518', '阳江'),
#  ('37168926957', '阳江'),
#  ('00865532303176', '阳江'),
#  ('00862869334824', '阳江'),
#  ('95093217', '阳江'),
#  ('00862938043563', '阳江'),
#  ('051983625529', '阳江'),
#  ('57128353876', '阳江'),
#  ('00862131226416', '阳江'),
#  ('17079258866', '阳江'),
#  ('57456277432', '阳江'),
#  ('00862061890752', '阳江'),
#  ('9516785454', '阳江'),
#  ('00868318795643', '阳江'),
#  ('008695714023', '阳江'),
#  ('00867902104014', '阳江'),
#  ('00862467984408', '阳江'),
#  ('00861053565852', '阳江'),
#  ('13360064238', '阳江'),
#  ('15158467116', '阳江'),
#  ('17622912791', '阳江'),
#  ('00863705821593', '阳江'),
#  ('57157165441', '阳江'),
#  ('18042170171', '阳江'),
#  ('17035456082', '阳江'),
#  ('51081994548', '阳江'),
#  ('00867902106577', '阳江'),
#  ('00864127173244', '阳江'),
#  ('00862985711171', '阳江'),
#  ('17121195778', '阳江'),
#  ('87168116387', '阳江'),
#  ('00869375979960', '阳江'),
#  ('00868396026750', '阳江'),
#  ('00868175290698', '阳江'),
#  ('18128987572', '阳江'),
#  ('00867303079246', '阳江'),
#  ('00864578925994', '阳江'),
#  ('57156390256', '阳江'),
#  ('00866628844113', '阳江'),
#  ('008695714121', '阳江'),
#  ('95054149', '阳江'),
#  ('00862863120017', '阳江'),
#  ('14754520890', '阳江'),
#  ('00867928914064', '阳江'),
#  ('51668921374', '阳江'),
#  ('13067867817', '阳江'),
#  ('18368123569', '阳江'),
#  ('00863723824740', '阳江'),
#  ('13392407479', '阳江'),
#  ('00868387108900', '阳江'),
#  ('13883347483', '阳江'),
#  ('00866628844116', '阳江'),
#  ('17392455626', '阳江'),
#  ('00867962133472', '云浮'),
#  ('00867303053032', '阳江'),
#  ('00867303079394', '阳江'),
#  ('00862867390250', '阳江'),
#  ('15909303579', '云浮'),
#  ('183********', '云浮'),
#  ('15758405153', '云浮'),
#  ('00864578925569', '阳江'),
#  ('13177850673', '阳江'),
#  ('87168117435', '阳江'),
#  ('00865532617354', '阳江'),
#  ('37163330145', '阳江'),
#  ('00864578926075', '阳江'),
#  ('95054164', '阳江'),
#  ('00867303050078', '阳江'),
#  ('19952479232', '阳江'),
#  ('19965144213', '阳江'),
#  ('15269169236', '阳江'),
#  ('00862887784372', '阳江'),
#  ('95075041', '云浮'),
#  ('00862156295390', '阳江'),
#  ('57156236540', '阳江'),
#  ('18680070784', '阳江'),
#  ('13262322176', '阳江'),
#  ('00864578925808', '云浮'),
#  ('18658801892', '云浮'),
#  ('15905776865', '阳江'),
#  ('19969203974', '阳江'),
#  ('13587775627', '阳江'),
#  ('51081971503', '云浮'),
#  ('13089231894', '阳江'),
#  ('008695714160', '阳江'),
#  ('18929798039', '阳江'),
#  ('37960674407', '阳江'),
#  ('00864642949391', '云浮'),
#  ('57585689404', '阳江'),
#  ('19921675907', '阳江'),
#  ('00863723824905', '阳江'),
#  ('37960674342', '佛山'),
#  ('075528397802', '阳江'),
#  ('87168623371', '云浮'),
#  ('37163330847', '云浮'),
#  ('00865532624044', '阳江'),
#  ('13110574332', '阳江'),
#  ('00868386401581', '阳江'),
#  ('95054247', '阳江'),
#  ('18695627417', '阳江'),
#  ('15219971101', '阳江'),
#  ('00864578926214', '阳江'),
#  ('00866628844117', '阳江'),
#  ('18668102186', '阳江'),
#  ('15764411792', '云浮'),
#  ('15906617534', '阳江'),
#  ('00862467962719', '阳江'),
#  ('15606981545', '阳江'),
#  ('13107625878', '阳江'),
#  ('13395705982', '阳江'),
#  ('15267802981', '阳江'),
#  ('13001677805', '阳江'),
#  ('00864127172860', '阳江'),
#  ('51080574169', '阳江'),
#  ('15224098417', '阳江'),
#  ('17815107911', '阳江'),
#  ('00864642943645', '阳江'),
#  ('18357683528', '阳江'),
#  ('57487014119', '阳江'),
#  ('95561', '阳江'),
#  ('51080564823', '阳江'),
#  ('95202664', '阳江'),
#  ('00862120435100', '阳江'),
#  ('075566618836', '阳江'),
#  ('17688894036', '阳江'),
#  ('15986284807', '阳江'),
#  ('37163331472', '阳江'),
#  ('51080564508', '阳江'),
#  ('87168623529', '阳江'),
#  ('13117899814', '阳江'),
#  ('00867303050663', '阳江'),
#  ('51080564613', '阳江'),
#  ('13023839217', '阳江'),
#  ('00862860612955', '阳江'),
#  ('13227325791', '阳江'),
#  ('18655402853', '阳江'),
#  ('9516720658', '阳江'),
#  ('13557578710', '阳江'),
#  ('00867902104042', '阳江'),
#  ('37163330482', '阳江'),
#  ('00862965633124', '阳江'),
#  ('17177282234', '阳江'),
#  ('00867303050300', '阳江'),
#  ('13055957037', '阳江'),
#  ('00867303050719', '阳江'),
#  ('13992764214', '阳江'),
#  ('00867303050731', '阳江'),
#  ('00862965639215', '阳江'),
#  ('00862965639194', '阳江'),
#  ('00867303050708', '阳江'),
#  ('00862151970986', '阳江'),
#  ('00862965639295', '阳江'),
#  ('00861052593185', '阳江'),
#  ('00861053816481', '阳江'),
#  ('13025647770', '阳江'),
#  ('51080554279', '阳江'),
#  ('95202630', '阳江'),
#  ('00869375969869', '阳江'),
#  ('008695714133', '阳江'),
#  ('00867303050669', '阳江'),
#  ('18666856343', '阳江'),
#  ('13093801537', '阳江'),
#  ('13291967289', '阳江'),
#  ('00862362734821', '阳江'),
#  ('87168118338', '阳江'),
#  ('18826709948', '阳江'),
#  ('00862467984273', '阳江'),
#  ('00869375967123', '阳江'),
#  ('00863705820604', '阳江'),
#  ('00862965633600', '阳江'),
#  ('87168128571', '阳江'),
#  ('00862131579334', '阳江'),
#  ('00862467984145', '阳江'),
#  ('57456111725', '阳江'),
#  ('00867303051387', '阳江'),
#  ('15986289276', '阳江'),
#  ('15372732036', '阳江'),
#  ('00867928914012', '阳江'),
#  ('51080564527', '阳江'),
#  ('13542618988', '阳江'),
#  ('13187929408', '阳江'),
#  ('00868708888963', '阳江'),
#  ('75561664907', '阳江'),
#  ('00865722924941', '阳江'),
#  ('00869521292495', '阳江'),
#  ('00862467984483', '阳江'),
#  ('51484694142', '阳江'),
#  ('00862467984105', '阳江'),
#  ('51080564818', '阳江'),
#  ('00867303050659', '阳江'),
#  ('7892179', '阳江'),
#  ('00868878947027', '阳江'),
#  ('15393912609', '阳江'),
#  ('00867303051287', '阳江'),
#  ('00862467984194', '阳江'),
#  ('13221091307', '阳江'),
#  ('87168117440', '阳江'),
#  ('00867303050702', '阳江'),
#  ('87168116324', '阳江'),
#  ('18650299637', '阳江'),
#  ('18023805905', '阳江'),
#  ('00867303050718', '阳江'),
#  ('13610334861', '阳江'),
#  ('57128914173', '阳江'),
#  ('00867303050712', '阳江'),
#  ('00864127171162', '阳江'),
#  ('15769186554', '阳江'),
#  ('53159832387', '阳江'),
#  ('18813986477', '阳江'),
#  ('13006827478', '阳江'),
#  ('15559153285', '阳江'),
#  ('87168116797', '阳江'),
#  ('00867303050250', '阳江'),
#  ('00867303050727', '阳江'),
#  ('19957892651', '阳江'),
#  ('57156983379', '阳江'),
#  ('37156291032', '阳江'),
#  ('57128914125', '阳江'),
#  ('37158500951', '阳江'),
#  ('9516720660', '阳江'),
#  ('00867902104113', '阳江'),
#  ('51283985472', '阳江'),
#  ('15659105198', '阳江'),
#  ('037166395059', '阳江'),
#  ('00862552155351', '阳江'),
#  ('15559527661', '阳江'),
#  ('00862131298755', '阳江'),
#  ('00862467984529', '阳江'),
#  ('00867303050721', '阳江'),
#  ('57128914185', '阳江'),
#  ('00867902104025', '阳江'),
#  ('18971289732', '阳江'),
#  ('37156621623', '阳江'),
#  ('51081995046', '阳江'),
#  ('00867303050331', '阳江'),
#  ('15819199639', '阳江'),
#  ('75536343224', '阳江'),
#  ('13008143356', '阳江'),
#  ('15972801145', '阳江'),
#  ('00862938051665', '阳江'),
#  ('00867303050252', '阳江'),
#  ('13829839328', '阳江'),
#  ('18658850827', '阳江'),
#  ('75566894218', '阳江'),
#  ('00862867390396', '阳江'),
#  ('13110934537', '阳江'),
#  ('00861053876559', '阳江'),
#  ('13110934503', '阳江'),
#  ('18291748382', '阳江'),
#  ('18666879621', '阳江'),
#  ('00867303050638', '阳江'),
#  ('00862131341477', '阳江'),
#  ('00861052921902', '阳江'),
#  ('00862151874336', '阳江'),
#  ('19957890957', '阳江'),
#  ('18922175422', '阳江'),
#  ('15605060554', '阳江'),
#  ('18664030290', '阳江'),
#  ('18148883792', '阳江'),
#  ('00862467962454', '阳江'),
#  ('00867303050230', '阳江'),
#  ('17177286969', '阳江'),
#  ('15218183159', '阳江'),
#  ('57156317252', '阳江'),
#  ('00862131341480', '阳江'),
#  ('00862160387827', '阳江'),
#  ('00862151874335', '阳江'),
#  ('00861053565853', '阳江'),
#  ('00866627713239', '阳江'),
#  ('00862131341478', '阳江'),
#  ('00865356736244', '阳江'),
#  ('00867902104295', '阳江'),
#  ('76988036173', '阳江'),
#  ('00863357064598', '阳江'),
#  ('00862388762462', '阳江'),
#  ('18650581617', '阳江'),
#  ('57128234262', '阳江'),
#  ('00862151874355', '阳江'),
#  ('17371282831', '阳江'),
#  ('57156984647', '阳江'),
#  ('00862131341463', '阳江'),
#  ('00867902106534', '阳江'),
#  ('07668106333', '云浮'),
#  ('51480387497', '阳江'),
#  ('00865532624181', '阳江'),
#  ('00861053157031', '阳江'),
#  ('00862131341467', '阳江'),
#  ('00861067443497', '阳江'),
#  ('18633197524', '阳江'),
#  ('00861053916920', '阳江'),
#  ('00867303058839', '阳江'),
#  ('00865645225190', '阳江'),
#  ('18023839770', '阳江'),
#  ('00869513808159', '阳江'),
#  ('00863705820703', '阳江'),
#  ('55167123694', '阳江'),
#  ('18729219646', '阳江'),
#  ('15612572607', '阳江'),
#  ('15194148817', '阳江'),
#  ('7820288', '阳江'),
#  ('13058580260', '阳江'),
#  ('13100882495', '阳江'),
#  ('18531761747', '阳江'),
#  ('87168017422', '阳江'),
#  ('4001130085', '阳江'),
#  ('18533772070', '阳江'),
#  ('13058587860', '阳江'),
#  ('00862938048667', '阳江'),
#  ('00861053157073', '阳江'),
#  ('00861053946512', '阳江'),
#  ('18575293872', '阳江'),
#  ('17177303200', '阳江'),
#  ('37156613121', '阳江'),
#  ('51081995489', '阳江'),
#  ('95219306', '阳江'),
#  ('76989774114', '阳江'),
#  ('95213451', '云浮'),
#  ('51282139415', '阳江'),
#  ('00862583761560', '阳江'),
#  ('13026843634', '阳江'),
#  ('00861053967642', '阳江'),
#  ('00861052801318', '阳江'),
#  ('17703200617', '阳江'),
#  ('18675794351', '阳江'),
#  ('00867902104117', '阳江'),
#  ('17364002712', '云浮'),
#  ('00865532623307', '阳江'),
#  ('9521291399', '阳江'),
#  ('15560606291', '阳江'),
#  ('9516785427', '阳江'),
#  ('18319656661', '阳江'),
#  ('00861052593850', '阳江'),
#  ('95054746', '阳江'),
#  ('00861053936534', '阳江'),
#  ('51081970567', '阳江'),
#  ('13702819133', '阳江'),
#  ('75566618836', '阳江'),
#  ('18145845687', '阳江'),
#  ('00862467984328', '阳江'),
#  ('13693617576', '阳江'),
#  ('00862362734532', '阳江'),
#  ('00868333642017', '阳江'),
#  ('17710508753', '阳江'),
#  ('13829838598', '阳江'),
#  ('13521516473', '阳江'),
#  ('13521410497', '阳江'),
#  ('15775904023', '阳江'),
#  ('16620023611', '阳江'),
#  ('18310655730', '阳江'),
#  ('13372443659', '阳江'),
#  ('17703308026', '阳江'),
#  ('00867303058940', '阳江'),
#  ('00862388762098', '阳江'),
#  ('15194148921', '阳江'),
#  ('13544452956', '阳江'),
#  ('15725910850', '阳江'),
#  ('13336586821', '阳江'),
#  ('17663010259', '阳江'),
#  ('00862467919459', '阳江'),
#  ('13222229857', '阳江'),
#  ('00862388762155', '阳江'),
#  ('17124431378', '阳江'),
#  ('7758888', '阳江'),
#  ('15752039762', '阳江'),
#  ('4006800388', '阳江'),
#  ('15365311843', '阳江'),
#  ('15168107871', '阳江'),
#  ('15165142781', '阳江'),
#  ('76933327014', '阳江'),
#  ('95149431', '阳江'),
#  ('17622822364', '阳江'),
#  ('00863357822156', '阳江'),
#  ('15112648268', '阳江'),
#  ('15647468290', '阳江'),
#  ('57164623110', '阳江'),
#  ('00861053565856', '阳江'),
#  ('57156984660', '阳江'),
#  ('00867902106676', '阳江'),
#  ('18813225775', '阳江'),
#  ('53159840301', '阳江'),
#  ('15525634304', '阳江'),
#  ('55165456345', '阳江'),
#  ('13829897123', '阳江'),
#  ('18033437138', '阳江'),
#  ('00862467919354', '阳江'),
#  ('15819519662', '阳江'),
#  ('13106272496', '阳江'),
#  ('57156074578', '阳江'),
#  ('15920403978', '阳江'),
#  ('13346166174', '阳江'),
#  ('17070321320', '阳江'),
#  ('51080353367', '阳江'),
#  ('17131942413', '阳江'),
#  ('00862467988382', '阳江'),
#  ('95588', '阳江'),
#  ('75561898078', '阳江'),
#  ('18658712711', '阳江'),
#  ('18967869353', '阳江'),
#  ('17020158086', '阳江'),
#  ('7892222', '阳江'),
#  ('4009998786', '阳江'),
#  ('13858751547', '阳江'),
#  ('13725621197', '阳江'),
#  ('18775794626', '阳江'),
#  ('13729819542', '阳江'),
#  ('15692873929', '阳江'),
#  ('13802819133', '阳江'),
#  ('55165457327', '阳江'),
#  ('37156671735', '阳江'),
#  ('00861053807131', '阳江'),
#  ('13415806873', '阳江'),
#  ('18124887067', '阳江'),
#  ('87168500459', '阳江'),
#  ('57156984640', '阳江'),
#  ('00862860617261', '阳江'),
#  ('18688774515', '阳江'),
#  ('95075345', '阳江'),
#  ('57156622014', '阳江'),
#  ('59585406739', '阳江'),
#  ('13007275805', '阳江'),
#  ('00862095508', '阳江'),
#  ('53158097746', '阳江'),
#  ('00867996318282', '阳江'),
#  ('15867038556', '阳江'),
#  ('37156755389', '阳江'),
#  ('95075485', '阳江'),
#  ('13170604709', '阳江'),
#  ('13124674236', '阳江'),
#  ('13306654271', '阳江'),
#  ('17310390572', '阳江'),
#  ('00862583245744', '阳江'),
#  ('00865532624123', '阳江'),
#  ('37156053434', '阳江'),
#  ('00862759743985', '阳江'),
#  ('15664741010', '阳江'),
#  ('15986264585', '阳江'),
#  ('37156297669', '阳江'),
#  ('15016355840', '阳江'),
#  ('13193328384', '阳江'),
#  ('13995922634', '阳江'),
#  ('00861053913642', '阳江'),
#  ('13255276032', '阳江'),
#  ('79182045506', '阳江'),
#  ('18672143383', '阳江'),
#  ('15356123334', '阳江'),
#  ('00862362734853', '阳江'),
#  ('37156753862', '阳江'),
#  ('13023675833', '阳江'),
#  ('13097072795', '阳江'),
#  ('18664193777', '阳江'),
#  ('4000000666', '阳江'),
#  ('15730023651', '阳江'),
#  ('18067730386', '阳江'),
#  ('53158010967', '阳江'),
#  ('4000271262', '阳江'),
#  ('02095508', '阳江'),
#  ('18367829808', '阳江'),
#  ('87168500468', '阳江'),
#  ('53158010686', '阳江'),
#  ('15015678543', '阳江'),
#  ('51080353230', '阳江'),
#  ('15336625130', '阳江'),
#  ('53158011480', '阳江'),
#  ('114', '阳江'),
#  ('53158010782', '阳江'),
#  ('15560617397', '阳江'),
#  ('00861011895108', '阳江'),
#  ('15586783350', '阳江'),
#  ('13672403212', '阳江'),
#  ('75566850655', '阳江'),
#  ('15984565721', '阳江'),
#  ('53158010150', '阳江'),
#  ('53158010649', '阳江'),
#  ('17357707717', '阳江'),
#  ('53158011290', '阳江'),
#  ('13033297051', '阳江'),
#  ('17622823642', '阳江'),
#  ('00866627823225', '阳江'),
#  ('17742005642', '云浮'),
#  ('13535560709', '广州'),
#  ('13553309130', '广州'),
#  ('57156279158', '阳江'),
#  ('15218884452', '广州'),
#  ('18351283991', '广州'),
#  ('53258650264', '广州'),
#  ('00867583143248', '佛山'),
#  ('02034389099', '广州'),
#  ('00862883469419', '广州'),
#  ('15508083447', '云浮'),
#  ('13922274352', '广州'),
#  ('00862938048658', '云浮'),
#  ('18211537496', '广州'),
#  ('15258409361', '广州'),
#  ('15606503579', '广州'),
#  ('13185539631', '广州'),
#  ('76988034172', '云浮'),
#  ('57156279164', '阳江'),
#  ...]
