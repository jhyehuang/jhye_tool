# %%
from lxml import etree
import requests
import chardet
from urllib.parse import urlencode #Python内置的HTTP请求库 
from requests.cookies import RequestsCookieJar

# %%
import sys
from selenium import webdriver
from selenium.webdriver.chrome.options import Options


chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
driver = webdriver.Chrome(executable_path='/home/zhijiehuang/chromedriver', options=chrome_options)
driver.get('https://rmfygg.court.gov.cn/web/rmfyportal/noticeinfo?noticeTypeCode=66')
content = driver.page_source
driver.close()

# %%
print(content)
# Out:
# <!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" class="aui ltr yui3-js-enabled webkit ltr js chrome chrome69 chrome69-0 linux secure" dir="ltr" lang="zh-CN"><div id="yui3-css-stamp" style="position: absolute !important; visibility: hidden !important" class=""></div><head> <title>最新公告 - 人民法院公告网</title> <meta name="viewport" content="width=device-width, initial-scale=0.1 ,user-scalable=yes" /> <meta name="apple-mobile-web-app-capable" content="yes" /> <meta name="format-detection" content="telephone=no" /> <meta content="text/html; charset=UTF-8" http-equiv="content-type" /> <link href="https://rmfygg.court.gov.cn/rmfy-common-theme/images/favicon.ico" rel="Shortcut Icon" /> <link href="https://rmfygg.court.gov.cn/web/rmfyportal/noticeinfo?noticeTypeCode=66" rel="canonical" /> <link href="https://rmfygg.court.gov.cn/web/rmfyportal/noticeinfo?noticeTypeCode=66" hreflang="x-default" rel="alternate" /> <link href="https://rmfygg.court.gov.cn/web/rmfyportal/noticeinfo?noticeTypeCo
# ...

# %%
root = etree.HTML(content)
proxys = root.xpath("//tbody[@class='rmfy-table-tbody']")
print(proxys)
# Out:
# [<Element tbody at 0x7f01e498ff88>]

# %%
proxys = proxys[0].xpath("./tr")
base_url='https://rmfygg.court.gov.cn'

# %%
for pic in proxys:
    row=pic.xpath("./td")
    print(row[0].xpath("./a/text()"))
    print(row[1].xpath("./a/@title")[0])
    print(base_url+row[1].xpath("./a/@href")[0])
    print(row[2].xpath("./a/text()"))
    print(row[3].xpath("./a/text()"))
# Out:
# 张文博、张伟
# https://rmfygg.court.gov.cn/web/rmfyportal/noticedetail?paramStr=7033626
# ['执行文书']
# ['2018-10-28']
# 孙艳军、董艳辉
# https://rmfygg.court.gov.cn/web/rmfyportal/noticedetail?paramStr=7034190
# ['执行文书']
# ['2018-10-28']
# 李虹伯
# https://rmfygg.court.gov.cn/web/rmfyportal/noticedetail?paramStr=7034060
# ['执行文书']
# ['2018-10-28']
# 黄鹏伟
# https://rmfygg.court.gov.cn/web/rmfyportal/noticedetail?paramStr=7034136
# ['执行文书']
# ['2018-10-28']
# 刘琦
# https://rmfygg.court.gov.cn/web/rmfyportal/noticedetail?paramStr=7033056
# ['执行文书']
# ['2018-10-28']
# 王胜利
# https://rmfygg.court.gov.cn/web/rmfyportal/noticedetail?paramStr=7036824
# ['执行文书']
# ['2018-10-28']
# 上海俊宇服饰有限公司
# https://rmfygg.court.gov.cn/web/rmfyportal/noticedetail?paramStr=7037491
# ['执行文书']
# ['2018-10-28']
# 梁树忠、北京万金山物资商贸有限公司
# https://rmfygg.court.gov.cn/web/rmfyportal/noticedetail?paramStr=7037962
# ['执行文书']
# ['2018-10-28']
# 马秋天
# https://rmfygg.court.gov.cn/web/rmfyportal/noticedetail?paramStr=7038129
# ['执行文书']
# ...

# %%
from selenium import webdriver
from urllib.parse import urlencode #Python内置的HTTP请求库 
#browser = webdriver.Firefox()
browser=webdriver.PhantomJS()
browser.get("https://rmfygg.court.gov.cn/web/rmfyportal/noticeinfo?noticeTypeCode=66")
#webdriver.support.ui.WebDriverWait(browser, 1).until(lambda x: x.find_element_by_id("gg-list")) 
content = browser.page_source.encode('utf-8', 'ignore')
#selector = Selector(text=browser.page_source)
print(content)
browser.close()
# Out:
# /home/zhijiehuang/anaconda3/lib/python3.6/site-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# ...

# %%
import random
ajax_url ='https://rmfygg.court.gov.cn/web/rmfyportal/noticeinfo?'
user_agents=[
    'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36 Edge/16.16299',
]
 
data = { 
        'p_p_id': 'noticelist_WAR_rmfynoticeListportlet',
        'p_p_lifecycle': '2',
        'p_p_state': 'normal',
        'p_p_mode': 'view',
        'p_p_resource_id': 'initNoticeList',
        'p_p_cacheability': 'cacheLevelPage',
        'p_p_col_id': '50',
        'p_p_col_count': '1'}
body = { 
        '_noticelist_WAR_rmfynoticeListportlet_content': '',
        '_noticelist_WAR_rmfynoticeListportlet_searchContent': '',
        '_noticelist_WAR_rmfynoticeListportlet_courtParam': '',
        '_noticelist_WAR_rmfynoticeListportlet_IEVersion': 'ie',
        '_noticelist_WAR_rmfynoticeListportlet_flag': 'init',
        '_noticelist_WAR_rmfynoticeListportlet_noticeType': '66',
        '_noticelist_WAR_rmfynoticeListportlet_noticeTypeVal': '执行文书',
        '_noticelist_WAR_rmfynoticeListportlet_aoData': [{"name":"sEcho","value":1},{"name":"iColumns","value":6},
                                                         {"name":"sColumns","value":",,,,,"},
                                                         {"name":"iDisplayStart","value":0},
                                                         {"name":"iDisplayLength","value":15},
                                                         {"name":"mDataProp_0","value":None},
                                                         {"name":"mDataProp_1","value":None},
                                                         {"name":"mDataProp_2","value":None},
                                                         {"name":"mDataProp_3","value":None},
                                                         {"name":"mDataProp_4","value":None},{"name":"mDataProp_5","value":None}]
}

headers={
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'zh-CN,zh;q=0.8,zh-TW;q=0.7,zh-HK;q=0.5,en-US;q=0.3,en;q=0.2',
    'Cache-Control': 'max-age=0',
    'Referer': 'https://rmfygg.court.gov.cn/web/rmfyportal/noticeinfo?noticeTypeCode=66',
    'Connection': 'keep-alive',
    'Content-Length': '1097',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:62.0) Gecko/20100101 Firefox/62.0',
    'X-Anit-Forge-Code': '0',
    'X-Anit-Forge-Token': 'None',
    'X-Requested-With': 'XMLHttpRequest',
    'TE': 'Trailers',
   # 'Host': 'rmfygg.court.gov.cn'
}
mycookie={"ZZDATA1273632440":"949620883-1539740924-|1539763205", "JSESSIONID":"D3DAA65617938024F649FEDB19AA6A40",
          "LFR_SESSION_STATE_20158":"1539766501789", "tgw_l7_route":"fb4686ab27ce2dbeb7cbdd7edefce9f4", 
          "UM_distinctid":"1667fe8289a6a-07306e6478125d-4c312878-e1000-1667fe8289b1ce"}
x = requests.session()
x.get(url='https://rmfygg.court.gov.cn/web/rmfyportal/noticeinfo?noticeTypeCode=66')
#requests.utils.add_dict_to_cookiejar(x.cookies,mycookie)
#print(x.cookies['JSESSIONID'])
url = ajax_url+ urlencode(data) #拼接UR


resp = x.post(url=url,data=body,headers=headers)
if r.status_code == 200:
    print(r.json())  # 返回json格式的响应内容
print(resp)
# Out:
# {'iTotalRecords': 0, 'iTotalDisplayRecords': 0, 'data': []}
# <Response [200]>

# %%
heads = {}
heads['User-Agent'] = 'Mozilla/5.0 ' \
                          '(Macintosh; U; Intel Mac OS X 10_6_8; en-us) AppleWebKit/534.50 ' \
                          '(KHTML, like Gecko) Version/5.1 Safari/534.50'
s=requests.session()
response = s.get(url='https://rmfygg.court.gov.cn/web/rmfyportal/noticeinfo?noticeTypeCode=66',headers=heads, )
print(response.text)
root = etree.HTML(response.text)
# Out:
# <!DOCTYPE html> <html class="aui ltr" dir="ltr" lang="zh-CN"> <head> <title>最新公告 - 人民法院公告网</title> <meta name="viewport" content="width=device-width, initial-scale=0.1 ,user-scalable=yes" /> <meta name="apple-mobile-web-app-capable" content="yes" /> <meta name="format-detection" content="telephone=no" /> <meta content="text/html; charset=UTF-8" http-equiv="content-type" /> <link href="https://rmfygg.court.gov.cn/rmfy-common-theme/images/favicon.ico" rel="Shortcut Icon" /> <link href="https&#x3a;&#x2f;&#x2f;rmfygg&#x2e;court&#x2e;gov&#x2e;cn&#x2f;web&#x2f;rmfyportal&#x2f;noticeinfo&#x3f;noticeTypeCode&#x3d;66" rel="canonical" /> <link href="https&#x3a;&#x2f;&#x2f;rmfygg&#x2e;court&#x2e;gov&#x2e;cn&#x2f;web&#x2f;rmfyportal&#x2f;noticeinfo&#x3f;noticeTypeCode&#x3d;66" hreflang="x-default" rel="alternate" /> <link href="https&#x3a;&#x2f;&#x2f;rmfygg&#x2e;court&#x2e;gov&#x2e;cn&#x2f;web&#x2f;rmfyportal&#x2f;noticeinfo&#x3f;noticeTypeCode&#x3d;66" hreflang="zh-CN" rel="alternate" /> <link 
# ...

# %%
proxys = root.xpath("//tbody[@class='rmfy-table-tbody']")

# %%
proxys = proxys[0].xpath("./tr")

# %%
proxys
# Out:
# []

# %%
for x in proxys:
    print(x.text)

# %%
import requests
import json
r = requests.get('http://172.18.19.219:10082/?types=0&count=5&country=国内')
ip_ports = json.loads(r.text)
print(ip_ports)
ip = ip_ports[0][0]
port = ip_ports[0][1]
proxies={
    'http':'http://%s:%s'%(ip,port),
    'https':'http://%s:%s'%(ip,port)
}
r = requests.get('http://ip.chinaz.com/',proxies=proxies)
r.encoding='utf-8'
print(r.text)
# Out:
# [['125.70.13.77', 8080, 10], ['175.148.78.174', 1133, 9], ['118.190.95.35', 9001, 10], ['49.71.81.26', 3128, 10], ['61.183.233.6', 54896, 10]]
# ...
